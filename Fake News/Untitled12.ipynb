# %%
# !unzip train.csv.zip
# Out:
# Archive:  train.csv.zip
#   inflating: train.csv

# %%
import numpy as np
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# printing the stopwords in English
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# loading the dataset to a pandas DataFrame
news_data= pd.read_csv('train.csv')

# %%
news_data
# Out:
#           id                                              title  \
# 0          0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1          1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2          2                  Why the Truth Might Get You Fired
# 3          3  15 Civilians Killed In Single US Airstrike Hav...
# 4          4  Iranian woman jailed for fictional unpublished...
# ...      ...                                                ...
# 20795  20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799  20799                          What Keeps the F-35 Alive
#
#                                           author  \
# 0                                  Darrell Lucus
# 1                                Daniel J. Flynn
# 2                             Consortiumnews.com
# 3                                Jessica Purkiss
# 4                                 Howard Portnoy
# ...                                          ...
# 20795                              Jerome Hudson
# 20796                           Benjamin Hoffman
# 20797  Michael J. de la Merced and Rachel Abrams
# 20798                                Alex Ansary
# 20799                              David Swanson
#
#                                                     text  label
# 0      House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1      Ever get the feeling your life circles the rou...      0
# 2      Why the Truth Might Get You Fired October 29, ...      1
# 3      Videos 15 Civilians Killed In Single US Airstr...      1
# 4      Print \nAn Iranian woman has been sentenced to...      1
# ...                                                  ...    ...
# 20795  Rapper T. I. unloaded on black celebrities who...      0
# 20796  When the Green Bay Packers lost to the Washing...      0
# 20797  The Macy’s of today grew from the union of sev...      0
# 20798  NATO, Russia To Hold Parallel Exercises In Bal...      1
# 20799    David Swanson is an author, activist, journa...      1
#
# [20800 rows x 5 columns]

# %%
news_data = news_data.fillna('')

# %%
news_data['content'] = news_data['author']+' '+news_data['title']

# %%
# separating the data & label
x = news_data.drop(columns='label', axis=1)
Y = news_data['label']

# %%
port_stem = PorterStemmer()

# %%
def stemming(content):
    stemmed_content = re.sub('[^a-zA-Z]',' ',content)
    stemmed_content = stemmed_content.lower()
    stemmed_content = stemmed_content.split()
    stemmed_content = [port_stem.stem(word) for word in stemmed_content if not word in stopwords.words('english')]
    stemmed_content = ' '.join(stemmed_content)
    return stemmed_content

# %%
news_data['content'] = news_data['content'].apply(stemming)
# Out:
# Streaming output truncated to the last 5000 lines.
#  Clinton  FBIGate and the true depth of the ObamaGeddon
#  clinton  fbigate and the true depth of the obamageddon
# ['clinton', 'fbigate', 'and', 'the', 'true', 'depth', 'of', 'the', 'obamageddon']
# ['clinton', 'fbigat', 'true', 'depth', 'obamageddon']
# clinton fbigat true depth obamageddon
# Jafe Arnoldski  noreply blogger com  Head of Turkish delegation to Russia   The Crimean people s choice must be recognized
# jafe arnoldski  noreply blogger com  head of turkish delegation to russia   the crimean people s choice must be recognized
# ['jafe', 'arnoldski', 'noreply', 'blogger', 'com', 'head', 'of', 'turkish', 'delegation', 'to', 'russia', 'the', 'crimean', 'people', 's', 'choice', 'must', 'be', 'recognized']
# ['jafe', 'arnoldski', 'norepli', 'blogger', 'com', 'head', 'turkish', 'deleg', 'russia', 'crimean', 'peopl', 'choic', 'must', 'recogn']
# jafe arnoldski norepli blogger com head turkish deleg russia crimean peopl choic must recogn
# RT Toxic chemicals found in children s Halloween makeup   study
# rt toxic chemicals found in children s halloween makeup   study
# ['rt', 'toxic', 'chemicals', 'found', 'in', 'children', 's', 'halloween', 'makeup', 'study']
# ['rt', 'toxic', 'chemic', 'found', 'children', 'halloween', 'makeup', 'studi']
# rt toxic chemic found children halloween makeup studi
# Joseph Olson
# joseph olson
# ['joseph', 'olson']
# ['joseph', 'olson']
# joseph olson
# Madeline GaiaPortal   Serrated torches cleave the undesired
# madeline gaiaportal   serrated torches cleave the undesired
# ['madeline', 'gaiaportal', 'serrated', 'torches', 'cleave', 'the', 'undesired']
# ['madelin', 'gaiaport', 'serrat', 'torch', 'cleav', 'undesir']
# madelin gaiaport serrat torch cleav undesir
# Relampago Furioso Will There Be Riots In America The Day After Donald Trump Wins The Presidency
# relampago furioso will there be riots in america the day after donald trump wins the presidency
# ['relampago', 'furioso', 'will', 'there', 'be', 'riots', 'in', 'america', 'the', 'day', 'after', 'donald', 'trump', 'wins', 'the', 'presidency']
# ['relampago', 'furioso', 'riot', 'america', 'day', 'donald', 'trump', 'win', 'presid']
# relampago furioso riot america day donald trump win presid
# Joel B  Pollak Trump Drops Truth Bombs on Cuba Regime  Policies   Breitbart
# joel b  pollak trump drops truth bombs on cuba regime  policies   breitbart
# ['joel', 'b', 'pollak', 'trump', 'drops', 'truth', 'bombs', 'on', 'cuba', 'regime', 'policies', 'breitbart']
# ['joel', 'b', 'pollak', 'trump', 'drop', 'truth', 'bomb', 'cuba', 'regim', 'polici', 'breitbart']
# joel b pollak trump drop truth bomb cuba regim polici breitbart
# Robert J  Marlow USA Today Sports Writer Bashes Tom Brady  Praises Colin Kaepernick   Breitbart
# robert j  marlow usa today sports writer bashes tom brady  praises colin kaepernick   breitbart
# ['robert', 'j', 'marlow', 'usa', 'today', 'sports', 'writer', 'bashes', 'tom', 'brady', 'praises', 'colin', 'kaepernick', 'breitbart']
# ['robert', 'j', 'marlow', 'usa', 'today', 'sport', 'writer', 'bash', 'tom', 'bradi', 'prais', 'colin', 'kaepernick', 'breitbart']
# robert j marlow usa today sport writer bash tom bradi prais colin kaepernick breitbart
# Nellie Bailey and Glen Ford Black Agenda Radio for Week of Nov
# nellie bailey and glen ford black agenda radio for week of nov
# ['nellie', 'bailey', 'and', 'glen', 'ford', 'black', 'agenda', 'radio', 'for', 'week', 'of', 'nov']
# ['nelli', 'bailey', 'glen', 'ford', 'black', 'agenda', 'radio', 'week', 'nov']
# nelli bailey glen ford black agenda radio week nov
# Chris Tomlinson Islamic State Targeting Spanish Coastal Resort Towns
# chris tomlinson islamic state targeting spanish coastal resort towns
# ['chris', 'tomlinson', 'islamic', 'state', 'targeting', 'spanish', 'coastal', 'resort', 'towns']
# ['chri', 'tomlinson', 'islam', 'state', 'target', 'spanish', 'coastal', 'resort', 'town']
# chri tomlinson islam state target spanish coastal resort town
# Jenna Leigh Richardson Going Green  Marijuana Wins Big During Election
# jenna leigh richardson going green  marijuana wins big during election
# ['jenna', 'leigh', 'richardson', 'going', 'green', 'marijuana', 'wins', 'big', 'during', 'election']
# ['jenna', 'leigh', 'richardson', 'go', 'green', 'marijuana', 'win', 'big', 'elect']
# jenna leigh richardson go green marijuana win big elect
# curriec
# curriec
# ['curriec']
# ['curriec']
# curriec
# Jerome Hudson Hollywood  Media Mercilessly Mock Kellyanne Conway s Trump Inauguration Outfit
# jerome hudson hollywood  media mercilessly mock kellyanne conway s trump inauguration outfit
# ['jerome', 'hudson', 'hollywood', 'media', 'mercilessly', 'mock', 'kellyanne', 'conway', 's', 'trump', 'inauguration', 'outfit']
# ['jerom', 'hudson', 'hollywood', 'media', 'mercilessli', 'mock', 'kellyann', 'conway', 'trump', 'inaugur', 'outfit']
# jerom hudson hollywood media mercilessli mock kellyann conway trump inaugur outfit
# admin Europe on eve of banking ARMAGEDDON which will dwarf      global crash  warns expert   how does this affect YOU
# admin europe on eve of banking armageddon which will dwarf      global crash  warns expert   how does this affect you
# ['admin', 'europe', 'on', 'eve', 'of', 'banking', 'armageddon', 'which', 'will', 'dwarf', 'global', 'crash', 'warns', 'expert', 'how', 'does', 'this', 'affect', 'you']
# ['admin', 'europ', 'eve', 'bank', 'armageddon', 'dwarf', 'global', 'crash', 'warn', 'expert', 'affect']
# admin europ eve bank armageddon dwarf global crash warn expert affect
# Jerome Hudson Medical Examiner  Chris Cornell Committed Suicide By Hanging
# jerome hudson medical examiner  chris cornell committed suicide by hanging
# ['jerome', 'hudson', 'medical', 'examiner', 'chris', 'cornell', 'committed', 'suicide', 'by', 'hanging']
# ['jerom', 'hudson', 'medic', 'examin', 'chri', 'cornel', 'commit', 'suicid', 'hang']
# jerom hudson medic examin chri cornel commit suicid hang
# John Carney Trump Considering  Explosive  Executive Order on Unfair Trade
# john carney trump considering  explosive  executive order on unfair trade
# ['john', 'carney', 'trump', 'considering', 'explosive', 'executive', 'order', 'on', 'unfair', 'trade']
# ['john', 'carney', 'trump', 'consid', 'explos', 'execut', 'order', 'unfair', 'trade']
# john carney trump consid explos execut order unfair trade
# Patrick Healy Donald Trump and Hillary Clinton Struggle to Be Unifying Voice for Nation   The New York Times
# patrick healy donald trump and hillary clinton struggle to be unifying voice for nation   the new york times
# ['patrick', 'healy', 'donald', 'trump', 'and', 'hillary', 'clinton', 'struggle', 'to', 'be', 'unifying', 'voice', 'for', 'nation', 'the', 'new', 'york', 'times']
# ['patrick', 'heali', 'donald', 'trump', 'hillari', 'clinton', 'struggl', 'unifi', 'voic', 'nation', 'new', 'york', 'time']
# patrick heali donald trump hillari clinton struggl unifi voic nation new york time
# Virginia Hale Police Punched  Kicked While on Routine Patrol in Migrant Dominated Suburb   Breitbart
# virginia hale police punched  kicked while on routine patrol in migrant dominated suburb   breitbart
# ['virginia', 'hale', 'police', 'punched', 'kicked', 'while', 'on', 'routine', 'patrol', 'in', 'migrant', 'dominated', 'suburb', 'breitbart']
# ['virginia', 'hale', 'polic', 'punch', 'kick', 'routin', 'patrol', 'migrant', 'domin', 'suburb', 'breitbart']
# virginia hale polic punch kick routin patrol migrant domin suburb breitbart
# John W  Whitehead The path to total Dictatorship  America s Shadow Government and its silent coup
# john w  whitehead the path to total dictatorship  america s shadow government and its silent coup
# ['john', 'w', 'whitehead', 'the', 'path', 'to', 'total', 'dictatorship', 'america', 's', 'shadow', 'government', 'and', 'its', 'silent', 'coup']
# ['john', 'w', 'whitehead', 'path', 'total', 'dictatorship', 'america', 'shadow', 'govern', 'silent', 'coup']
# john w whitehead path total dictatorship america shadow govern silent coup
# Christine Hauser Delta Air Lines Bans Disruptive Donald Trump Supporter for Life   The New York Times
# christine hauser delta air lines bans disruptive donald trump supporter for life   the new york times
# ['christine', 'hauser', 'delta', 'air', 'lines', 'bans', 'disruptive', 'donald', 'trump', 'supporter', 'for', 'life', 'the', 'new', 'york', 'times']
# ['christin', 'hauser', 'delta', 'air', 'line', 'ban', 'disrupt', 'donald', 'trump', 'support', 'life', 'new', 'york', 'time']
# christin hauser delta air line ban disrupt donald trump support life new york time
# Mohamed
# mohamed
# ['mohamed']
# ['moham']
# moham
# David Stockman Wall Street s Calling The Sheep To The Slaughter  Again
# david stockman wall street s calling the sheep to the slaughter  again
# ['david', 'stockman', 'wall', 'street', 's', 'calling', 'the', 'sheep', 'to', 'the', 'slaughter', 'again']
# ['david', 'stockman', 'wall', 'street', 'call', 'sheep', 'slaughter']
# david stockman wall street call sheep slaughter
# Jennifer Steinhauer  Jeremy W  Peters and Amy Chozick Clinton Campaign Demands Intelligence on Possible Russian Efforts to Elect Trump   The New York Times
# jennifer steinhauer  jeremy w  peters and amy chozick clinton campaign demands intelligence on possible russian efforts to elect trump   the new york times
# ['jennifer', 'steinhauer', 'jeremy', 'w', 'peters', 'and', 'amy', 'chozick', 'clinton', 'campaign', 'demands', 'intelligence', 'on', 'possible', 'russian', 'efforts', 'to', 'elect', 'trump', 'the', 'new', 'york', 'times']
# ['jennif', 'steinhauer', 'jeremi', 'w', 'peter', 'ami', 'chozick', 'clinton', 'campaign', 'demand', 'intellig', 'possibl', 'russian', 'effort', 'elect', 'trump', 'new', 'york', 'time']
# jennif steinhauer jeremi w peter ami chozick clinton campaign demand intellig possibl russian effort elect trump new york time
# Francine Prose Enthralled by Sicily  Again   The New York Times
# francine prose enthralled by sicily  again   the new york times
# ['francine', 'prose', 'enthralled', 'by', 'sicily', 'again', 'the', 'new', 'york', 'times']
# ['francin', 'prose', 'enthral', 'sicili', 'new', 'york', 'time']
# francin prose enthral sicili new york time
# Daniel Victor Clinton to Trump on Twitter   Delete Your Account    The New York Times
# daniel victor clinton to trump on twitter   delete your account    the new york times
# ['daniel', 'victor', 'clinton', 'to', 'trump', 'on', 'twitter', 'delete', 'your', 'account', 'the', 'new', 'york', 'times']
# ['daniel', 'victor', 'clinton', 'trump', 'twitter', 'delet', 'account', 'new', 'york', 'time']
# daniel victor clinton trump twitter delet account new york time
# Eddy Lavine These Products Make Men Grow Breasts  Get Cancers Of The Prostate And Liver
# eddy lavine these products make men grow breasts  get cancers of the prostate and liver
# ['eddy', 'lavine', 'these', 'products', 'make', 'men', 'grow', 'breasts', 'get', 'cancers', 'of', 'the', 'prostate', 'and', 'liver']
# ['eddi', 'lavin', 'product', 'make', 'men', 'grow', 'breast', 'get', 'cancer', 'prostat', 'liver']
# eddi lavin product make men grow breast get cancer prostat liver
# Breitbart Jerusalem Sarah Netanyahu Tells Melania Trump of Common Bond   Media Hate Us but the People Love Us
# breitbart jerusalem sarah netanyahu tells melania trump of common bond   media hate us but the people love us
# ['breitbart', 'jerusalem', 'sarah', 'netanyahu', 'tells', 'melania', 'trump', 'of', 'common', 'bond', 'media', 'hate', 'us', 'but', 'the', 'people', 'love', 'us']
# ['breitbart', 'jerusalem', 'sarah', 'netanyahu', 'tell', 'melania', 'trump', 'common', 'bond', 'media', 'hate', 'us', 'peopl', 'love', 'us']
# breitbart jerusalem sarah netanyahu tell melania trump common bond media hate us peopl love us
# Pavel Tarasenko  Las presiones de EE UU y la OTAN han influido en Espa a    Noticias de Rusia   RBTH
# pavel tarasenko  las presiones de ee uu y la otan han influido en espa a    noticias de rusia   rbth
# ['pavel', 'tarasenko', 'las', 'presiones', 'de', 'ee', 'uu', 'y', 'la', 'otan', 'han', 'influido', 'en', 'espa', 'a', 'noticias', 'de', 'rusia', 'rbth']
# ['pavel', 'tarasenko', 'la', 'presion', 'de', 'ee', 'uu', 'la', 'otan', 'han', 'influido', 'en', 'espa', 'noticia', 'de', 'rusia', 'rbth']
# pavel tarasenko la presion de ee uu la otan han influido en espa noticia de rusia rbth
# Corbett The Corbett Report  Accept no substitutes
# corbett the corbett report  accept no substitutes
# ['corbett', 'the', 'corbett', 'report', 'accept', 'no', 'substitutes']
# ['corbett', 'corbett', 'report', 'accept', 'substitut']
# corbett corbett report accept substitut
# Eric Zuesse  Saudi Arabia to behead disabled man who peacefully protested
# eric zuesse  saudi arabia to behead disabled man who peacefully protested
# ['eric', 'zuesse', 'saudi', 'arabia', 'to', 'behead', 'disabled', 'man', 'who', 'peacefully', 'protested']
# ['eric', 'zuess', 'saudi', 'arabia', 'behead', 'disabl', 'man', 'peac', 'protest']
# eric zuess saudi arabia behead disabl man peac protest
# Karml
# karml
# ['karml']
# ['karml']
# karml
# Charlie Savage Chelsea Manning Describes Bleak Life in a Men s Prison   The New York Times
# charlie savage chelsea manning describes bleak life in a men s prison   the new york times
# ['charlie', 'savage', 'chelsea', 'manning', 'describes', 'bleak', 'life', 'in', 'a', 'men', 's', 'prison', 'the', 'new', 'york', 'times']
# ['charli', 'savag', 'chelsea', 'man', 'describ', 'bleak', 'life', 'men', 'prison', 'new', 'york', 'time']
# charli savag chelsea man describ bleak life men prison new york time
# Redacci n A o       Los Pa ses Enanos piden que se les llame Pa ses Bajos
# redacci n a o       los pa ses enanos piden que se les llame pa ses bajos
# ['redacci', 'n', 'a', 'o', 'los', 'pa', 'ses', 'enanos', 'piden', 'que', 'se', 'les', 'llame', 'pa', 'ses', 'bajos']
# ['redacci', 'n', 'lo', 'pa', 'se', 'enano', 'piden', 'que', 'se', 'le', 'llame', 'pa', 'se', 'bajo']
# redacci n lo pa se enano piden que se le llame pa se bajo
# Karen Zraick and Lisa Iaboni Donald Trump  Chicago Police  Your Friday Evening Briefing   The New York Times
# karen zraick and lisa iaboni donald trump  chicago police  your friday evening briefing   the new york times
# ['karen', 'zraick', 'and', 'lisa', 'iaboni', 'donald', 'trump', 'chicago', 'police', 'your', 'friday', 'evening', 'briefing', 'the', 'new', 'york', 'times']
# ['karen', 'zraick', 'lisa', 'iaboni', 'donald', 'trump', 'chicago', 'polic', 'friday', 'even', 'brief', 'new', 'york', 'time']
# karen zraick lisa iaboni donald trump chicago polic friday even brief new york time
# smith j      Projections to     Electoral Votes
# smith j      projections to     electoral votes
# ['smith', 'j', 'projections', 'to', 'electoral', 'votes']
# ['smith', 'j', 'project', 'elector', 'vote']
# smith j project elector vote
# WakingTimes Not Just Bees  Trees Are Dying Off at an Alarming Rate With Little Public Attention
# wakingtimes not just bees  trees are dying off at an alarming rate with little public attention
# ['wakingtimes', 'not', 'just', 'bees', 'trees', 'are', 'dying', 'off', 'at', 'an', 'alarming', 'rate', 'with', 'little', 'public', 'attention']
# ['wakingtim', 'bee', 'tree', 'die', 'alarm', 'rate', 'littl', 'public', 'attent']
# wakingtim bee tree die alarm rate littl public attent
# Neil Munro Vanity Fair  National Politics Are all About Donald Trump s Wall   Breitbart
# neil munro vanity fair  national politics are all about donald trump s wall   breitbart
# ['neil', 'munro', 'vanity', 'fair', 'national', 'politics', 'are', 'all', 'about', 'donald', 'trump', 's', 'wall', 'breitbart']
# ['neil', 'munro', 'vaniti', 'fair', 'nation', 'polit', 'donald', 'trump', 'wall', 'breitbart']
# neil munro vaniti fair nation polit donald trump wall breitbart
# Neal E  Boudette The Superglue Diet  How to Make a Lighter  Fuel Sipping Car   The New York Times
# neal e  boudette the superglue diet  how to make a lighter  fuel sipping car   the new york times
# ['neal', 'e', 'boudette', 'the', 'superglue', 'diet', 'how', 'to', 'make', 'a', 'lighter', 'fuel', 'sipping', 'car', 'the', 'new', 'york', 'times']
# ['neal', 'e', 'boudett', 'superglu', 'diet', 'make', 'lighter', 'fuel', 'sip', 'car', 'new', 'york', 'time']
# neal e boudett superglu diet make lighter fuel sip car new york time
# Harry Abrams
# harry abrams
# ['harry', 'abrams']
# ['harri', 'abram']
# harri abram
#  Occult Expert Breaks Down Wikileaks Exposed Clinton Campaign Satanism   TruthFeed
#  occult expert breaks down wikileaks exposed clinton campaign satanism   truthfeed
# ['occult', 'expert', 'breaks', 'down', 'wikileaks', 'exposed', 'clinton', 'campaign', 'satanism', 'truthfeed']
# ['occult', 'expert', 'break', 'wikileak', 'expos', 'clinton', 'campaign', 'satan', 'truthfe']
# occult expert break wikileak expos clinton campaign satan truthfe
# shorty Reading the News in Times of Empire
# shorty reading the news in times of empire
# ['shorty', 'reading', 'the', 'news', 'in', 'times', 'of', 'empire']
# ['shorti', 'read', 'news', 'time', 'empir']
# shorti read news time empir
#  CLINTON CAMPAIGN CHAIRMAN HAD MULTIPLE DINNERS WITH TOP DOJ OFFICIAL DURING HILLARY S EMAIL INVESTIGATION
#  clinton campaign chairman had multiple dinners with top doj official during hillary s email investigation
# ['clinton', 'campaign', 'chairman', 'had', 'multiple', 'dinners', 'with', 'top', 'doj', 'official', 'during', 'hillary', 's', 'email', 'investigation']
# ['clinton', 'campaign', 'chairman', 'multipl', 'dinner', 'top', 'doj', 'offici', 'hillari', 'email', 'investig']
# clinton campaign chairman multipl dinner top doj offici hillari email investig
# Donna Rachel Edmunds Jewish Voter Threatened By Crowbar Weilding Man Shouting  Kill All the Jews  at London Polling Station
# donna rachel edmunds jewish voter threatened by crowbar weilding man shouting  kill all the jews  at london polling station
# ['donna', 'rachel', 'edmunds', 'jewish', 'voter', 'threatened', 'by', 'crowbar', 'weilding', 'man', 'shouting', 'kill', 'all', 'the', 'jews', 'at', 'london', 'polling', 'station']
# ['donna', 'rachel', 'edmund', 'jewish', 'voter', 'threaten', 'crowbar', 'weild', 'man', 'shout', 'kill', 'jew', 'london', 'poll', 'station']
# donna rachel edmund jewish voter threaten crowbar weild man shout kill jew london poll station
# Amy Moreno Telegraph  Journalist  Calls For the Assassination of Donald Trump The Deletes Her Twitter Account   TruthFeed
# amy moreno telegraph  journalist  calls for the assassination of donald trump the deletes her twitter account   truthfeed
# ['amy', 'moreno', 'telegraph', 'journalist', 'calls', 'for', 'the', 'assassination', 'of', 'donald', 'trump', 'the', 'deletes', 'her', 'twitter', 'account', 'truthfeed']
# ['ami', 'moreno', 'telegraph', 'journalist', 'call', 'assassin', 'donald', 'trump', 'delet', 'twitter', 'account', 'truthfe']
# ami moreno telegraph journalist call assassin donald trump delet twitter account truthfe
# Graham Bowley Judge Allows Testimony of Another Accuser in Cosby Case   The New York Times
# graham bowley judge allows testimony of another accuser in cosby case   the new york times
# ['graham', 'bowley', 'judge', 'allows', 'testimony', 'of', 'another', 'accuser', 'in', 'cosby', 'case', 'the', 'new', 'york', 'times']
# ['graham', 'bowley', 'judg', 'allow', 'testimoni', 'anoth', 'accus', 'cosbi', 'case', 'new', 'york', 'time']
# graham bowley judg allow testimoni anoth accus cosbi case new york time
# Dr  Susan Berry Pennsylvania Abortion Clinic Shut Down by Health Department
# dr  susan berry pennsylvania abortion clinic shut down by health department
# ['dr', 'susan', 'berry', 'pennsylvania', 'abortion', 'clinic', 'shut', 'down', 'by', 'health', 'department']
# ['dr', 'susan', 'berri', 'pennsylvania', 'abort', 'clinic', 'shut', 'health', 'depart']
# dr susan berri pennsylvania abort clinic shut health depart
# Jerome Hudson Madonna Drops F Bombs at Anti Trump Rally   I ve Thought a Lot About Blowing Up the White House
# jerome hudson madonna drops f bombs at anti trump rally   i ve thought a lot about blowing up the white house
# ['jerome', 'hudson', 'madonna', 'drops', 'f', 'bombs', 'at', 'anti', 'trump', 'rally', 'i', 've', 'thought', 'a', 'lot', 'about', 'blowing', 'up', 'the', 'white', 'house']
# ['jerom', 'hudson', 'madonna', 'drop', 'f', 'bomb', 'anti', 'trump', 'ralli', 'thought', 'lot', 'blow', 'white', 'hous']
# jerom hudson madonna drop f bomb anti trump ralli thought lot blow white hous
# Joel B  Pollak Dershowitz  Special Counsel Is Wrong Choice  Except to Investigate Leaks   Breitbart
# joel b  pollak dershowitz  special counsel is wrong choice  except to investigate leaks   breitbart
# ['joel', 'b', 'pollak', 'dershowitz', 'special', 'counsel', 'is', 'wrong', 'choice', 'except', 'to', 'investigate', 'leaks', 'breitbart']
# ['joel', 'b', 'pollak', 'dershowitz', 'special', 'counsel', 'wrong', 'choic', 'except', 'investig', 'leak', 'breitbart']
# joel b pollak dershowitz special counsel wrong choic except investig leak breitbart
# Angel   NYC Conflicting Accounts Emerge After Treaty Camp Police Action
# angel   nyc conflicting accounts emerge after treaty camp police action
# ['angel', 'nyc', 'conflicting', 'accounts', 'emerge', 'after', 'treaty', 'camp', 'police', 'action']
# ['angel', 'nyc', 'conflict', 'account', 'emerg', 'treati', 'camp', 'polic', 'action']
# angel nyc conflict account emerg treati camp polic action
# Lucas Nolan WikiLeaks  CIA  Pandemic  Malware Infected Servers to Spread Virus to Computers   Breitbart
# lucas nolan wikileaks  cia  pandemic  malware infected servers to spread virus to computers   breitbart
# ['lucas', 'nolan', 'wikileaks', 'cia', 'pandemic', 'malware', 'infected', 'servers', 'to', 'spread', 'virus', 'to', 'computers', 'breitbart']
# ['luca', 'nolan', 'wikileak', 'cia', 'pandem', 'malwar', 'infect', 'server', 'spread', 'viru', 'comput', 'breitbart']
# luca nolan wikileak cia pandem malwar infect server spread viru comput breitbart
# Brenda Walker Sick Hillary Needed a Doctor in the Oval Office during Coughing Fit
# brenda walker sick hillary needed a doctor in the oval office during coughing fit
# ['brenda', 'walker', 'sick', 'hillary', 'needed', 'a', 'doctor', 'in', 'the', 'oval', 'office', 'during', 'coughing', 'fit']
# ['brenda', 'walker', 'sick', 'hillari', 'need', 'doctor', 'oval', 'offic', 'cough', 'fit']
# brenda walker sick hillari need doctor oval offic cough fit
# Brooks Barnes Marvel s  Inhumans  TV Series Will Arrive via Imax Theaters   The New York Times
# brooks barnes marvel s  inhumans  tv series will arrive via imax theaters   the new york times
# ['brooks', 'barnes', 'marvel', 's', 'inhumans', 'tv', 'series', 'will', 'arrive', 'via', 'imax', 'theaters', 'the', 'new', 'york', 'times']
# ['brook', 'barn', 'marvel', 'inhuman', 'tv', 'seri', 'arriv', 'via', 'imax', 'theater', 'new', 'york', 'time']
# brook barn marvel inhuman tv seri arriv via imax theater new york time
# Jerome Hudson Eric Holder s Airbnb Runs Controversial  WeAccept Multiculturalism Ad   Breitbart
# jerome hudson eric holder s airbnb runs controversial  weaccept multiculturalism ad   breitbart
# ['jerome', 'hudson', 'eric', 'holder', 's', 'airbnb', 'runs', 'controversial', 'weaccept', 'multiculturalism', 'ad', 'breitbart']
# ['jerom', 'hudson', 'eric', 'holder', 'airbnb', 'run', 'controversi', 'weaccept', 'multicultur', 'ad', 'breitbart']
# jerom hudson eric holder airbnb run controversi weaccept multicultur ad breitbart
# Katherine Rodriguez Study  American Adults Having Less Sex than a Quarter of a Century Ago   Breitbart
# katherine rodriguez study  american adults having less sex than a quarter of a century ago   breitbart
# ['katherine', 'rodriguez', 'study', 'american', 'adults', 'having', 'less', 'sex', 'than', 'a', 'quarter', 'of', 'a', 'century', 'ago', 'breitbart']
# ['katherin', 'rodriguez', 'studi', 'american', 'adult', 'less', 'sex', 'quarter', 'centuri', 'ago', 'breitbart']
# katherin rodriguez studi american adult less sex quarter centuri ago breitbart
# Joel B  Pollak Fake News Plus Fascism  New York Times Urges Boycott of Breitbart
# joel b  pollak fake news plus fascism  new york times urges boycott of breitbart
# ['joel', 'b', 'pollak', 'fake', 'news', 'plus', 'fascism', 'new', 'york', 'times', 'urges', 'boycott', 'of', 'breitbart']
# ['joel', 'b', 'pollak', 'fake', 'news', 'plu', 'fascism', 'new', 'york', 'time', 'urg', 'boycott', 'breitbart']
# joel b pollak fake news plu fascism new york time urg boycott breitbart
# Mike Isaac Facebook Blocks Ad Blockers  but It Strives to Make Ads More Relevant   The New York Times
# mike isaac facebook blocks ad blockers  but it strives to make ads more relevant   the new york times
# ['mike', 'isaac', 'facebook', 'blocks', 'ad', 'blockers', 'but', 'it', 'strives', 'to', 'make', 'ads', 'more', 'relevant', 'the', 'new', 'york', 'times']
# ['mike', 'isaac', 'facebook', 'block', 'ad', 'blocker', 'strive', 'make', 'ad', 'relev', 'new', 'york', 'time']
# mike isaac facebook block ad blocker strive make ad relev new york time
# Geoffrey Grider A Defeated Obama Condescendingly Mocks Winner Trump  Says  He Can t Keep Campaign Promises
# geoffrey grider a defeated obama condescendingly mocks winner trump  says  he can t keep campaign promises
# ['geoffrey', 'grider', 'a', 'defeated', 'obama', 'condescendingly', 'mocks', 'winner', 'trump', 'says', 'he', 'can', 't', 'keep', 'campaign', 'promises']
# ['geoffrey', 'grider', 'defeat', 'obama', 'condescendingli', 'mock', 'winner', 'trump', 'say', 'keep', 'campaign', 'promis']
# geoffrey grider defeat obama condescendingli mock winner trump say keep campaign promis
# Michelle Malkin A Fifth Clinton Presidency  Hill  No
# michelle malkin a fifth clinton presidency  hill  no
# ['michelle', 'malkin', 'a', 'fifth', 'clinton', 'presidency', 'hill', 'no']
# ['michel', 'malkin', 'fifth', 'clinton', 'presid', 'hill']
# michel malkin fifth clinton presid hill
# Corbett James Ellroy s  American Tabloid    Film  Literature and the New World Order
# corbett james ellroy s  american tabloid    film  literature and the new world order
# ['corbett', 'james', 'ellroy', 's', 'american', 'tabloid', 'film', 'literature', 'and', 'the', 'new', 'world', 'order']
# ['corbett', 'jame', 'ellroy', 'american', 'tabloid', 'film', 'literatur', 'new', 'world', 'order']
# corbett jame ellroy american tabloid film literatur new world order
#  Japan  US  S Korea Deputy FMs to Discuss N Korea Nuclear Issue Thursday
#  japan  us  s korea deputy fms to discuss n korea nuclear issue thursday
# ['japan', 'us', 's', 'korea', 'deputy', 'fms', 'to', 'discuss', 'n', 'korea', 'nuclear', 'issue', 'thursday']
# ['japan', 'us', 'korea', 'deputi', 'fm', 'discuss', 'n', 'korea', 'nuclear', 'issu', 'thursday']
# japan us korea deputi fm discuss n korea nuclear issu thursday
# Eric Lipton and Noah Weiland Trump Puts a Presidential Size Spotlight on His Brand   The New York Times
# eric lipton and noah weiland trump puts a presidential size spotlight on his brand   the new york times
# ['eric', 'lipton', 'and', 'noah', 'weiland', 'trump', 'puts', 'a', 'presidential', 'size', 'spotlight', 'on', 'his', 'brand', 'the', 'new', 'york', 'times']
# ['eric', 'lipton', 'noah', 'weiland', 'trump', 'put', 'presidenti', 'size', 'spotlight', 'brand', 'new', 'york', 'time']
# eric lipton noah weiland trump put presidenti size spotlight brand new york time
# Jeff Dunetz The Clintons  original email scandal  One million lost emails in re Monica and Filegate
# jeff dunetz the clintons  original email scandal  one million lost emails in re monica and filegate
# ['jeff', 'dunetz', 'the', 'clintons', 'original', 'email', 'scandal', 'one', 'million', 'lost', 'emails', 'in', 're', 'monica', 'and', 'filegate']
# ['jeff', 'dunetz', 'clinton', 'origin', 'email', 'scandal', 'one', 'million', 'lost', 'email', 'monica', 'fileg']
# jeff dunetz clinton origin email scandal one million lost email monica fileg
# Guest Post Unprecedented Bond Dumping Means U S  Dollar Collapse Ahead
# guest post unprecedented bond dumping means u s  dollar collapse ahead
# ['guest', 'post', 'unprecedented', 'bond', 'dumping', 'means', 'u', 's', 'dollar', 'collapse', 'ahead']
# ['guest', 'post', 'unpreced', 'bond', 'dump', 'mean', 'u', 'dollar', 'collaps', 'ahead']
# guest post unpreced bond dump mean u dollar collaps ahead
# AWR Hawkins Kansas Rally Against Campus Carry Draws    People
# awr hawkins kansas rally against campus carry draws    people
# ['awr', 'hawkins', 'kansas', 'rally', 'against', 'campus', 'carry', 'draws', 'people']
# ['awr', 'hawkin', 'kansa', 'ralli', 'campu', 'carri', 'draw', 'peopl']
# awr hawkin kansa ralli campu carri draw peopl
# Alex Ansary Topless Protesters Arrested At Trump s Polling Station
# alex ansary topless protesters arrested at trump s polling station
# ['alex', 'ansary', 'topless', 'protesters', 'arrested', 'at', 'trump', 's', 'polling', 'station']
# ['alex', 'ansari', 'topless', 'protest', 'arrest', 'trump', 'poll', 'station']
# alex ansari topless protest arrest trump poll station
#  Most Russians wan to ignore criticism from the West
#  most russians wan to ignore criticism from the west
# ['most', 'russians', 'wan', 'to', 'ignore', 'criticism', 'from', 'the', 'west']
# ['russian', 'wan', 'ignor', 'critic', 'west']
# russian wan ignor critic west
# Milad Amini Movahhed Why Muslims Hold the Biggest Human Gathering under the Threat of ISIS in Iraq
# milad amini movahhed why muslims hold the biggest human gathering under the threat of isis in iraq
# ['milad', 'amini', 'movahhed', 'why', 'muslims', 'hold', 'the', 'biggest', 'human', 'gathering', 'under', 'the', 'threat', 'of', 'isis', 'in', 'iraq']
# ['milad', 'amini', 'movah', 'muslim', 'hold', 'biggest', 'human', 'gather', 'threat', 'isi', 'iraq']
# milad amini movah muslim hold biggest human gather threat isi iraq
# Daniel McAdams Election        Prediction Of Things To Come
# daniel mcadams election        prediction of things to come
# ['daniel', 'mcadams', 'election', 'prediction', 'of', 'things', 'to', 'come']
# ['daniel', 'mcadam', 'elect', 'predict', 'thing', 'come']
# daniel mcadam elect predict thing come
# Dr  Edward F  Group III    Foods High In Folic Acid
# dr  edward f  group iii    foods high in folic acid
# ['dr', 'edward', 'f', 'group', 'iii', 'foods', 'high', 'in', 'folic', 'acid']
# ['dr', 'edward', 'f', 'group', 'iii', 'food', 'high', 'folic', 'acid']
# dr edward f group iii food high folic acid
# Breitbart Tech Michael Wolff on MILO s  Dangerous   Publishing Is a Business   Breitbart
# breitbart tech michael wolff on milo s  dangerous   publishing is a business   breitbart
# ['breitbart', 'tech', 'michael', 'wolff', 'on', 'milo', 's', 'dangerous', 'publishing', 'is', 'a', 'business', 'breitbart']
# ['breitbart', 'tech', 'michael', 'wolff', 'milo', 'danger', 'publish', 'busi', 'breitbart']
# breitbart tech michael wolff milo danger publish busi breitbart
# Warner Todd Huston Fox Sports   s Jason Whitlock Slams Sports Media for its Drive to the Left   Breitbart
# warner todd huston fox sports   s jason whitlock slams sports media for its drive to the left   breitbart
# ['warner', 'todd', 'huston', 'fox', 'sports', 's', 'jason', 'whitlock', 'slams', 'sports', 'media', 'for', 'its', 'drive', 'to', 'the', 'left', 'breitbart']
# ['warner', 'todd', 'huston', 'fox', 'sport', 'jason', 'whitlock', 'slam', 'sport', 'media', 'drive', 'left', 'breitbart']
# warner todd huston fox sport jason whitlock slam sport media drive left breitbart
# Katherine Rodriguez Breitbart Editor in Chief Alex Marlow Interviews Rep  Kevin Brady at CPAC  We re Going to End the Tax on  Made in America    Breitbart
# katherine rodriguez breitbart editor in chief alex marlow interviews rep  kevin brady at cpac  we re going to end the tax on  made in america    breitbart
# ['katherine', 'rodriguez', 'breitbart', 'editor', 'in', 'chief', 'alex', 'marlow', 'interviews', 'rep', 'kevin', 'brady', 'at', 'cpac', 'we', 're', 'going', 'to', 'end', 'the', 'tax', 'on', 'made', 'in', 'america', 'breitbart']
# ['katherin', 'rodriguez', 'breitbart', 'editor', 'chief', 'alex', 'marlow', 'interview', 'rep', 'kevin', 'bradi', 'cpac', 'go', 'end', 'tax', 'made', 'america', 'breitbart']
# katherin rodriguez breitbart editor chief alex marlow interview rep kevin bradi cpac go end tax made america breitbart
# Nick Denby
# nick denby
# ['nick', 'denby']
# ['nick', 'denbi']
# nick denbi
# Deborah Danan Russians In Israel Advised Not To Say  Schmuck  Or Get Drunk
# deborah danan russians in israel advised not to say  schmuck  or get drunk
# ['deborah', 'danan', 'russians', 'in', 'israel', 'advised', 'not', 'to', 'say', 'schmuck', 'or', 'get', 'drunk']
# ['deborah', 'danan', 'russian', 'israel', 'advis', 'say', 'schmuck', 'get', 'drunk']
# deborah danan russian israel advis say schmuck get drunk
# My Catbird Seat Woodward On Clinton Foundation  It s Corrupt
# my catbird seat woodward on clinton foundation  it s corrupt
# ['my', 'catbird', 'seat', 'woodward', 'on', 'clinton', 'foundation', 'it', 's', 'corrupt']
# ['catbird', 'seat', 'woodward', 'clinton', 'foundat', 'corrupt']
# catbird seat woodward clinton foundat corrupt
# William C  Rhoden With Deflategate Ruling  Roger Goodell Is Firmly in Control   The New York Times
# william c  rhoden with deflategate ruling  roger goodell is firmly in control   the new york times
# ['william', 'c', 'rhoden', 'with', 'deflategate', 'ruling', 'roger', 'goodell', 'is', 'firmly', 'in', 'control', 'the', 'new', 'york', 'times']
# ['william', 'c', 'rhoden', 'deflateg', 'rule', 'roger', 'goodel', 'firmli', 'control', 'new', 'york', 'time']
# william c rhoden deflateg rule roger goodel firmli control new york time
# David Stockman Chart Of The Day  Trend Growth Rate Of Real GDP Has Slumped To       Year
# david stockman chart of the day  trend growth rate of real gdp has slumped to       year
# ['david', 'stockman', 'chart', 'of', 'the', 'day', 'trend', 'growth', 'rate', 'of', 'real', 'gdp', 'has', 'slumped', 'to', 'year']
# ['david', 'stockman', 'chart', 'day', 'trend', 'growth', 'rate', 'real', 'gdp', 'slump', 'year']
# david stockman chart day trend growth rate real gdp slump year
# dailouk EU Referendum  Betrayal of the People by Traitors in Undemocratic Coup
# dailouk eu referendum  betrayal of the people by traitors in undemocratic coup
# ['dailouk', 'eu', 'referendum', 'betrayal', 'of', 'the', 'people', 'by', 'traitors', 'in', 'undemocratic', 'coup']
# ['dailouk', 'eu', 'referendum', 'betray', 'peopl', 'traitor', 'undemocrat', 'coup']
# dailouk eu referendum betray peopl traitor undemocrat coup
# Michael Patrick Leahy Tuberculosis  Refugees Produce    Percent of Active Cases in New Hampshire   Breitbart
# michael patrick leahy tuberculosis  refugees produce    percent of active cases in new hampshire   breitbart
# ['michael', 'patrick', 'leahy', 'tuberculosis', 'refugees', 'produce', 'percent', 'of', 'active', 'cases', 'in', 'new', 'hampshire', 'breitbart']
# ['michael', 'patrick', 'leahi', 'tuberculosi', 'refuge', 'produc', 'percent', 'activ', 'case', 'new', 'hampshir', 'breitbart']
# michael patrick leahi tuberculosi refuge produc percent activ case new hampshir breitbart
# Natural News Editors Meet the journalist facing    years in jail for filming the tar sands pipeline protest in North Dakota
# natural news editors meet the journalist facing    years in jail for filming the tar sands pipeline protest in north dakota
# ['natural', 'news', 'editors', 'meet', 'the', 'journalist', 'facing', 'years', 'in', 'jail', 'for', 'filming', 'the', 'tar', 'sands', 'pipeline', 'protest', 'in', 'north', 'dakota']
# ['natur', 'news', 'editor', 'meet', 'journalist', 'face', 'year', 'jail', 'film', 'tar', 'sand', 'pipelin', 'protest', 'north', 'dakota']
# natur news editor meet journalist face year jail film tar sand pipelin protest north dakota
# Heather Callaghan Cannabis Protects The Brain From Traumatic Injuries And Concussions  Study Finds
# heather callaghan cannabis protects the brain from traumatic injuries and concussions  study finds
# ['heather', 'callaghan', 'cannabis', 'protects', 'the', 'brain', 'from', 'traumatic', 'injuries', 'and', 'concussions', 'study', 'finds']
# ['heather', 'callaghan', 'cannabi', 'protect', 'brain', 'traumat', 'injuri', 'concuss', 'studi', 'find']
# heather callaghan cannabi protect brain traumat injuri concuss studi find
# Sridhar Pappu Internet Porn Nearly Ruined His Life  Now He Wants to Help    The New York Times
# sridhar pappu internet porn nearly ruined his life  now he wants to help    the new york times
# ['sridhar', 'pappu', 'internet', 'porn', 'nearly', 'ruined', 'his', 'life', 'now', 'he', 'wants', 'to', 'help', 'the', 'new', 'york', 'times']
# ['sridhar', 'pappu', 'internet', 'porn', 'nearli', 'ruin', 'life', 'want', 'help', 'new', 'york', 'time']
# sridhar pappu internet porn nearli ruin life want help new york time
# Editor Magnetic storm could disrupt power grids  navigation systems and satellites over the next few days
# editor magnetic storm could disrupt power grids  navigation systems and satellites over the next few days
# ['editor', 'magnetic', 'storm', 'could', 'disrupt', 'power', 'grids', 'navigation', 'systems', 'and', 'satellites', 'over', 'the', 'next', 'few', 'days']
# ['editor', 'magnet', 'storm', 'could', 'disrupt', 'power', 'grid', 'navig', 'system', 'satellit', 'next', 'day']
# editor magnet storm could disrupt power grid navig system satellit next day
# Peter Baker Donald Trump s Victory Promises to Upend the International Order   The New York Times
# peter baker donald trump s victory promises to upend the international order   the new york times
# ['peter', 'baker', 'donald', 'trump', 's', 'victory', 'promises', 'to', 'upend', 'the', 'international', 'order', 'the', 'new', 'york', 'times']
# ['peter', 'baker', 'donald', 'trump', 'victori', 'promis', 'upend', 'intern', 'order', 'new', 'york', 'time']
# peter baker donald trump victori promis upend intern order new york time
# IWB Google Party Over  Alphabet Cracks Down on Costs  Layoffs Ensue  Division CEOs Quit
# iwb google party over  alphabet cracks down on costs  layoffs ensue  division ceos quit
# ['iwb', 'google', 'party', 'over', 'alphabet', 'cracks', 'down', 'on', 'costs', 'layoffs', 'ensue', 'division', 'ceos', 'quit']
# ['iwb', 'googl', 'parti', 'alphabet', 'crack', 'cost', 'layoff', 'ensu', 'divis', 'ceo', 'quit']
# iwb googl parti alphabet crack cost layoff ensu divis ceo quit
#  The Powerful Words of John Trudell Ring Out Over Standing Rock
#  the powerful words of john trudell ring out over standing rock
# ['the', 'powerful', 'words', 'of', 'john', 'trudell', 'ring', 'out', 'over', 'standing', 'rock']
# ['power', 'word', 'john', 'trudel', 'ring', 'stand', 'rock']
# power word john trudel ring stand rock
# Pete Wells The Top    New York Dishes of        The New York Times
# pete wells the top    new york dishes of        the new york times
# ['pete', 'wells', 'the', 'top', 'new', 'york', 'dishes', 'of', 'the', 'new', 'york', 'times']
# ['pete', 'well', 'top', 'new', 'york', 'dish', 'new', 'york', 'time']
# pete well top new york dish new york time
# Mike Merryman Lotze The Inherent Violence of Israel s Gaza Blockade
# mike merryman lotze the inherent violence of israel s gaza blockade
# ['mike', 'merryman', 'lotze', 'the', 'inherent', 'violence', 'of', 'israel', 's', 'gaza', 'blockade']
# ['mike', 'merryman', 'lotz', 'inher', 'violenc', 'israel', 'gaza', 'blockad']
# mike merryman lotz inher violenc israel gaza blockad
# Kimiko de Freytas Tamura    Psychiatric Patients in South Africa Died of Negligence  Report Finds   The New York Times
# kimiko de freytas tamura    psychiatric patients in south africa died of negligence  report finds   the new york times
# ['kimiko', 'de', 'freytas', 'tamura', 'psychiatric', 'patients', 'in', 'south', 'africa', 'died', 'of', 'negligence', 'report', 'finds', 'the', 'new', 'york', 'times']
# ['kimiko', 'de', 'freyta', 'tamura', 'psychiatr', 'patient', 'south', 'africa', 'die', 'neglig', 'report', 'find', 'new', 'york', 'time']
# kimiko de freyta tamura psychiatr patient south africa die neglig report find new york time
# Trent Baker MSNBC s Nance  Trump Has  Always Promised Autocracy   He s  Closest Thing We ve Ever Had to King George III    Breitbart
# trent baker msnbc s nance  trump has  always promised autocracy   he s  closest thing we ve ever had to king george iii    breitbart
# ['trent', 'baker', 'msnbc', 's', 'nance', 'trump', 'has', 'always', 'promised', 'autocracy', 'he', 's', 'closest', 'thing', 'we', 've', 'ever', 'had', 'to', 'king', 'george', 'iii', 'breitbart']
# ['trent', 'baker', 'msnbc', 'nanc', 'trump', 'alway', 'promis', 'autocraci', 'closest', 'thing', 'ever', 'king', 'georg', 'iii', 'breitbart']
# trent baker msnbc nanc trump alway promis autocraci closest thing ever king georg iii breitbart
# lostinnm
# lostinnm
# ['lostinnm']
# ['lostinnm']
# lostinnm
# Pete Kimberley Training French soldiers to supervise Daesh
# pete kimberley training french soldiers to supervise daesh
# ['pete', 'kimberley', 'training', 'french', 'soldiers', 'to', 'supervise', 'daesh']
# ['pete', 'kimberley', 'train', 'french', 'soldier', 'supervis', 'daesh']
# pete kimberley train french soldier supervis daesh
# Truthstream Media Video  We Now Have Proof Obamacare Was Designed to Fail  and Here s Why
# truthstream media video  we now have proof obamacare was designed to fail  and here s why
# ['truthstream', 'media', 'video', 'we', 'now', 'have', 'proof', 'obamacare', 'was', 'designed', 'to', 'fail', 'and', 'here', 's', 'why']
# ['truthstream', 'media', 'video', 'proof', 'obamacar', 'design', 'fail']
# truthstream media video proof obamacar design fail
# Richard A  Oppel Jr  In Tribute to Son  Khizr Khan Offered Citizenship Lesson at Convention   The New York Times
# richard a  oppel jr  in tribute to son  khizr khan offered citizenship lesson at convention   the new york times
# ['richard', 'a', 'oppel', 'jr', 'in', 'tribute', 'to', 'son', 'khizr', 'khan', 'offered', 'citizenship', 'lesson', 'at', 'convention', 'the', 'new', 'york', 'times']
# ['richard', 'oppel', 'jr', 'tribut', 'son', 'khizr', 'khan', 'offer', 'citizenship', 'lesson', 'convent', 'new', 'york', 'time']
# richard oppel jr tribut son khizr khan offer citizenship lesson convent new york time
# Joel B  Pollak Cohn  Trump Becoming  Smarter    More Knowledgeable  on Climate Change   Breitbart
# joel b  pollak cohn  trump becoming  smarter    more knowledgeable  on climate change   breitbart
# ['joel', 'b', 'pollak', 'cohn', 'trump', 'becoming', 'smarter', 'more', 'knowledgeable', 'on', 'climate', 'change', 'breitbart']
# ['joel', 'b', 'pollak', 'cohn', 'trump', 'becom', 'smarter', 'knowledg', 'climat', 'chang', 'breitbart']
# joel b pollak cohn trump becom smarter knowledg climat chang breitbart
# Kenneth Chang SpaceX Says It s Ready to Launch Rockets Again   The New York Times
# kenneth chang spacex says it s ready to launch rockets again   the new york times
# ['kenneth', 'chang', 'spacex', 'says', 'it', 's', 'ready', 'to', 'launch', 'rockets', 'again', 'the', 'new', 'york', 'times']
# ['kenneth', 'chang', 'spacex', 'say', 'readi', 'launch', 'rocket', 'new', 'york', 'time']
# kenneth chang spacex say readi launch rocket new york time
#  Woman faces jail for dismal selection of office birthday cakes
#  woman faces jail for dismal selection of office birthday cakes
# ['woman', 'faces', 'jail', 'for', 'dismal', 'selection', 'of', 'office', 'birthday', 'cakes']
# ['woman', 'face', 'jail', 'dismal', 'select', 'offic', 'birthday', 'cake']
# woman face jail dismal select offic birthday cake
#   We don t care about your red line   Turkey slams EU criticism over journalists  arrests   Russia News Now
#   we don t care about your red line   turkey slams eu criticism over journalists  arrests   russia news now
# ['we', 'don', 't', 'care', 'about', 'your', 'red', 'line', 'turkey', 'slams', 'eu', 'criticism', 'over', 'journalists', 'arrests', 'russia', 'news', 'now']
# ['care', 'red', 'line', 'turkey', 'slam', 'eu', 'critic', 'journalist', 'arrest', 'russia', 'news']
# care red line turkey slam eu critic journalist arrest russia news
# Jon Caramanica and Nate Chinen The Playlist  Barack Obama s Summery Playlists and Green Day s Fiery Return   The New York Times
# jon caramanica and nate chinen the playlist  barack obama s summery playlists and green day s fiery return   the new york times
# ['jon', 'caramanica', 'and', 'nate', 'chinen', 'the', 'playlist', 'barack', 'obama', 's', 'summery', 'playlists', 'and', 'green', 'day', 's', 'fiery', 'return', 'the', 'new', 'york', 'times']
# ['jon', 'caramanica', 'nate', 'chinen', 'playlist', 'barack', 'obama', 'summeri', 'playlist', 'green', 'day', 'fieri', 'return', 'new', 'york', 'time']
# jon caramanica nate chinen playlist barack obama summeri playlist green day fieri return new york time
# Tom s Fuentes Televisi n  lo m s visto ayer
# tom s fuentes televisi n  lo m s visto ayer
# ['tom', 's', 'fuentes', 'televisi', 'n', 'lo', 'm', 's', 'visto', 'ayer']
# ['tom', 'fuent', 'televisi', 'n', 'lo', 'visto', 'ayer']
# tom fuent televisi n lo visto ayer
# Robert J  Marlow Tiger Woods Withdraws from Two Tournaments   Don t Think I ll Ever Feel Great Again    Breitbart
# robert j  marlow tiger woods withdraws from two tournaments   don t think i ll ever feel great again    breitbart
# ['robert', 'j', 'marlow', 'tiger', 'woods', 'withdraws', 'from', 'two', 'tournaments', 'don', 't', 'think', 'i', 'll', 'ever', 'feel', 'great', 'again', 'breitbart']
# ['robert', 'j', 'marlow', 'tiger', 'wood', 'withdraw', 'two', 'tournament', 'think', 'ever', 'feel', 'great', 'breitbart']
# robert j marlow tiger wood withdraw two tournament think ever feel great breitbart
#  FBI Agents Must Come Forward to Confront Corruption
#  fbi agents must come forward to confront corruption
# ['fbi', 'agents', 'must', 'come', 'forward', 'to', 'confront', 'corruption']
# ['fbi', 'agent', 'must', 'come', 'forward', 'confront', 'corrupt']
# fbi agent must come forward confront corrupt
#  The De Facto US Al Qaeda Alliance
#  the de facto us al qaeda alliance
# ['the', 'de', 'facto', 'us', 'al', 'qaeda', 'alliance']
# ['de', 'facto', 'us', 'al', 'qaeda', 'allianc']
# de facto us al qaeda allianc
# Dan Wright Trump s Economic Program Set For Rough Reality
# dan wright trump s economic program set for rough reality
# ['dan', 'wright', 'trump', 's', 'economic', 'program', 'set', 'for', 'rough', 'reality']
# ['dan', 'wright', 'trump', 'econom', 'program', 'set', 'rough', 'realiti']
# dan wright trump econom program set rough realiti
# Pam Key Ryan on GOP Losing House Majority in        Blah  Blah  Blah    White Noise of Washington    Breitbart
# pam key ryan on gop losing house majority in        blah  blah  blah    white noise of washington    breitbart
# ['pam', 'key', 'ryan', 'on', 'gop', 'losing', 'house', 'majority', 'in', 'blah', 'blah', 'blah', 'white', 'noise', 'of', 'washington', 'breitbart']
# ['pam', 'key', 'ryan', 'gop', 'lose', 'hous', 'major', 'blah', 'blah', 'blah', 'white', 'nois', 'washington', 'breitbart']
# pam key ryan gop lose hous major blah blah blah white nois washington breitbart
# drrichard
# drrichard
# ['drrichard']
# ['drrichard']
# drrichard
# Nicholas Fandos Trump s View of Syria  How It Evolved  in    Tweets   The New York Times
# nicholas fandos trump s view of syria  how it evolved  in    tweets   the new york times
# ['nicholas', 'fandos', 'trump', 's', 'view', 'of', 'syria', 'how', 'it', 'evolved', 'in', 'tweets', 'the', 'new', 'york', 'times']
# ['nichola', 'fando', 'trump', 'view', 'syria', 'evolv', 'tweet', 'new', 'york', 'time']
# nichola fando trump view syria evolv tweet new york time
# Breitbart TV Watch  Pentagon Released Explosion Footage for  Mother of All Bombs  Dropped on Afghanistan   Breitbart
# breitbart tv watch  pentagon released explosion footage for  mother of all bombs  dropped on afghanistan   breitbart
# ['breitbart', 'tv', 'watch', 'pentagon', 'released', 'explosion', 'footage', 'for', 'mother', 'of', 'all', 'bombs', 'dropped', 'on', 'afghanistan', 'breitbart']
# ['breitbart', 'tv', 'watch', 'pentagon', 'releas', 'explos', 'footag', 'mother', 'bomb', 'drop', 'afghanistan', 'breitbart']
# breitbart tv watch pentagon releas explos footag mother bomb drop afghanistan breitbart
# Adam Nagourney Democrats  Divisions Linger  but Parties Have Seen Far Worse   The New York Times
# adam nagourney democrats  divisions linger  but parties have seen far worse   the new york times
# ['adam', 'nagourney', 'democrats', 'divisions', 'linger', 'but', 'parties', 'have', 'seen', 'far', 'worse', 'the', 'new', 'york', 'times']
# ...
# daniel leberfeld nfl preview  championship match ups prove teams without elite qb s wasting time   breitbart
# ['daniel', 'leberfeld', 'nfl', 'preview', 'championship', 'match', 'ups', 'prove', 'teams', 'without', 'elite', 'qb', 's', 'wasting', 'time', 'breitbart']
# ['daniel', 'leberfeld', 'nfl', 'preview', 'championship', 'match', 'up', 'prove', 'team', 'without', 'elit', 'qb', 'wast', 'time', 'breitbart']
# daniel leberfeld nfl preview championship match up prove team without elit qb wast time breitbart
# Penny Starr President Trump s Father s Day Proclamation  Dads Have Responsibility to  Instill in Us Core Values
# penny starr president trump s father s day proclamation  dads have responsibility to  instill in us core values
# ['penny', 'starr', 'president', 'trump', 's', 'father', 's', 'day', 'proclamation', 'dads', 'have', 'responsibility', 'to', 'instill', 'in', 'us', 'core', 'values']
# ['penni', 'starr', 'presid', 'trump', 'father', 'day', 'proclam', 'dad', 'respons', 'instil', 'us', 'core', 'valu']
# penni starr presid trump father day proclam dad respons instil us core valu
# Activist Post Former Ambassador Andrew Young Calls for End to Water Fluoridation   Civil Rights Issue
# activist post former ambassador andrew young calls for end to water fluoridation   civil rights issue
# ['activist', 'post', 'former', 'ambassador', 'andrew', 'young', 'calls', 'for', 'end', 'to', 'water', 'fluoridation', 'civil', 'rights', 'issue']
# ['activist', 'post', 'former', 'ambassador', 'andrew', 'young', 'call', 'end', 'water', 'fluorid', 'civil', 'right', 'issu']
# activist post former ambassador andrew young call end water fluorid civil right issu
#  Osama bin Laden s older brother rents out luxury student flats in Scotland
#  osama bin laden s older brother rents out luxury student flats in scotland
# ['osama', 'bin', 'laden', 's', 'older', 'brother', 'rents', 'out', 'luxury', 'student', 'flats', 'in', 'scotland']
# ['osama', 'bin', 'laden', 'older', 'brother', 'rent', 'luxuri', 'student', 'flat', 'scotland']
# osama bin laden older brother rent luxuri student flat scotland
# Pakalert WORLD WAR     Mr President        xFrozenLPx
# pakalert world war     mr president        xfrozenlpx
# ['pakalert', 'world', 'war', 'mr', 'president', 'xfrozenlpx']
# ['pakalert', 'world', 'war', 'mr', 'presid', 'xfrozenlpx']
# pakalert world war mr presid xfrozenlpx
# Iron Sheik HUMA ABEDIN SWORE UNDER OATH SHE GAVE UP  ALL THE DEVICES  WITH STATE DEPT  EMAILS
# iron sheik huma abedin swore under oath she gave up  all the devices  with state dept  emails
# ['iron', 'sheik', 'huma', 'abedin', 'swore', 'under', 'oath', 'she', 'gave', 'up', 'all', 'the', 'devices', 'with', 'state', 'dept', 'emails']
# ['iron', 'sheik', 'huma', 'abedin', 'swore', 'oath', 'gave', 'devic', 'state', 'dept', 'email']
# iron sheik huma abedin swore oath gave devic state dept email
# Letsbereal
# letsbereal
# ['letsbereal']
# ['letsber']
# letsber
# beersession
# beersession
# ['beersession']
# ['beersess']
# beersess
# Vicki Batts Australia to hunt down anti vax nurses and prosecute them for disobeying the medical police state
# vicki batts australia to hunt down anti vax nurses and prosecute them for disobeying the medical police state
# ['vicki', 'batts', 'australia', 'to', 'hunt', 'down', 'anti', 'vax', 'nurses', 'and', 'prosecute', 'them', 'for', 'disobeying', 'the', 'medical', 'police', 'state']
# ['vicki', 'batt', 'australia', 'hunt', 'anti', 'vax', 'nurs', 'prosecut', 'disobey', 'medic', 'polic', 'state']
# vicki batt australia hunt anti vax nurs prosecut disobey medic polic state
# Liam Deacon Government Report  Islamists Building  Parallel Society  in Sweden Aided By PC Culture
# liam deacon government report  islamists building  parallel society  in sweden aided by pc culture
# ['liam', 'deacon', 'government', 'report', 'islamists', 'building', 'parallel', 'society', 'in', 'sweden', 'aided', 'by', 'pc', 'culture']
# ['liam', 'deacon', 'govern', 'report', 'islamist', 'build', 'parallel', 'societi', 'sweden', 'aid', 'pc', 'cultur']
# liam deacon govern report islamist build parallel societi sweden aid pc cultur
# Arnaldo Rodgers How this WWII airman is helping veterans heal with the help of   legged friends
# arnaldo rodgers how this wwii airman is helping veterans heal with the help of   legged friends
# ['arnaldo', 'rodgers', 'how', 'this', 'wwii', 'airman', 'is', 'helping', 'veterans', 'heal', 'with', 'the', 'help', 'of', 'legged', 'friends']
# ['arnaldo', 'rodger', 'wwii', 'airman', 'help', 'veteran', 'heal', 'help', 'leg', 'friend']
# arnaldo rodger wwii airman help veteran heal help leg friend
# Jameson Parker Trump Campaign Says Hillary Supporter Tried Assassinating Trump   It Was A Republican With A Poster
# jameson parker trump campaign says hillary supporter tried assassinating trump   it was a republican with a poster
# ['jameson', 'parker', 'trump', 'campaign', 'says', 'hillary', 'supporter', 'tried', 'assassinating', 'trump', 'it', 'was', 'a', 'republican', 'with', 'a', 'poster']
# ['jameson', 'parker', 'trump', 'campaign', 'say', 'hillari', 'support', 'tri', 'assassin', 'trump', 'republican', 'poster']
# jameson parker trump campaign say hillari support tri assassin trump republican poster
# admin Editor of Austria s Largest Paper Charged with  Hate Speech  over Migrant Article
# admin editor of austria s largest paper charged with  hate speech  over migrant article
# ['admin', 'editor', 'of', 'austria', 's', 'largest', 'paper', 'charged', 'with', 'hate', 'speech', 'over', 'migrant', 'article']
# ['admin', 'editor', 'austria', 'largest', 'paper', 'charg', 'hate', 'speech', 'migrant', 'articl']
# admin editor austria largest paper charg hate speech migrant articl
# Neil Irwin This Is a Jobs Report That Democrats Can Boast About   The New York Times
# neil irwin this is a jobs report that democrats can boast about   the new york times
# ['neil', 'irwin', 'this', 'is', 'a', 'jobs', 'report', 'that', 'democrats', 'can', 'boast', 'about', 'the', 'new', 'york', 'times']
# ['neil', 'irwin', 'job', 'report', 'democrat', 'boast', 'new', 'york', 'time']
# neil irwin job report democrat boast new york time
# Thomas D  Williams  Ph D  Christians in       Most Persecuted Group in the World
# thomas d  williams  ph d  christians in       most persecuted group in the world
# ['thomas', 'd', 'williams', 'ph', 'd', 'christians', 'in', 'most', 'persecuted', 'group', 'in', 'the', 'world']
# ['thoma', 'william', 'ph', 'christian', 'persecut', 'group', 'world']
# thoma william ph christian persecut group world
# Christine Hauser Florida Woman Charged in Death of Infant in  Co Sleeping  Case   The New York Times
# christine hauser florida woman charged in death of infant in  co sleeping  case   the new york times
# ['christine', 'hauser', 'florida', 'woman', 'charged', 'in', 'death', 'of', 'infant', 'in', 'co', 'sleeping', 'case', 'the', 'new', 'york', 'times']
# ['christin', 'hauser', 'florida', 'woman', 'charg', 'death', 'infant', 'co', 'sleep', 'case', 'new', 'york', 'time']
# christin hauser florida woman charg death infant co sleep case new york time
# Heather Callaghan Time is Running Out to Stop Kratom Ban   Need Comments to DEA
# heather callaghan time is running out to stop kratom ban   need comments to dea
# ['heather', 'callaghan', 'time', 'is', 'running', 'out', 'to', 'stop', 'kratom', 'ban', 'need', 'comments', 'to', 'dea']
# ['heather', 'callaghan', 'time', 'run', 'stop', 'kratom', 'ban', 'need', 'comment', 'dea']
# heather callaghan time run stop kratom ban need comment dea
# The Doc The Fix Is In  NBC Affiliate Accidentally Posts Election Results A Week Early  Hillary Wins Presidency     to Trump s
# the doc the fix is in  nbc affiliate accidentally posts election results a week early  hillary wins presidency     to trump s
# ['the', 'doc', 'the', 'fix', 'is', 'in', 'nbc', 'affiliate', 'accidentally', 'posts', 'election', 'results', 'a', 'week', 'early', 'hillary', 'wins', 'presidency', 'to', 'trump', 's']
# ['doc', 'fix', 'nbc', 'affili', 'accident', 'post', 'elect', 'result', 'week', 'earli', 'hillari', 'win', 'presid', 'trump']
# doc fix nbc affili accident post elect result week earli hillari win presid trump
# Charles McDermid Samsung  Kim Jong un  Rex Tillerson  Your Morning Briefing   The New York Times
# charles mcdermid samsung  kim jong un  rex tillerson  your morning briefing   the new york times
# ['charles', 'mcdermid', 'samsung', 'kim', 'jong', 'un', 'rex', 'tillerson', 'your', 'morning', 'briefing', 'the', 'new', 'york', 'times']
# ['charl', 'mcdermid', 'samsung', 'kim', 'jong', 'un', 'rex', 'tillerson', 'morn', 'brief', 'new', 'york', 'time']
# charl mcdermid samsung kim jong un rex tillerson morn brief new york time
# Debbie Menon Comment on World Heaves Sigh of Relief after Trump s Victory by Debbie Menon
# debbie menon comment on world heaves sigh of relief after trump s victory by debbie menon
# ['debbie', 'menon', 'comment', 'on', 'world', 'heaves', 'sigh', 'of', 'relief', 'after', 'trump', 's', 'victory', 'by', 'debbie', 'menon']
# ['debbi', 'menon', 'comment', 'world', 'heav', 'sigh', 'relief', 'trump', 'victori', 'debbi', 'menon']
# debbi menon comment world heav sigh relief trump victori debbi menon
# Ann Coulter Ann Coulter  How to Provide Universal Health Care Using This One Easy Trick
# ann coulter ann coulter  how to provide universal health care using this one easy trick
# ['ann', 'coulter', 'ann', 'coulter', 'how', 'to', 'provide', 'universal', 'health', 'care', 'using', 'this', 'one', 'easy', 'trick']
# ['ann', 'coulter', 'ann', 'coulter', 'provid', 'univers', 'health', 'care', 'use', 'one', 'easi', 'trick']
# ann coulter ann coulter provid univers health care use one easi trick
#  Government Forces Advancing at Damascus Aleppo Highway in Eastern Ghouta
#  government forces advancing at damascus aleppo highway in eastern ghouta
# ['government', 'forces', 'advancing', 'at', 'damascus', 'aleppo', 'highway', 'in', 'eastern', 'ghouta']
# ['govern', 'forc', 'advanc', 'damascu', 'aleppo', 'highway', 'eastern', 'ghouta']
# govern forc advanc damascu aleppo highway eastern ghouta
# Ian Mason Sally Yates Won t Say If Trump Was Wiretapped   Breitbart
# ian mason sally yates won t say if trump was wiretapped   breitbart
# ['ian', 'mason', 'sally', 'yates', 'won', 't', 'say', 'if', 'trump', 'was', 'wiretapped', 'breitbart']
# ['ian', 'mason', 'salli', 'yate', 'say', 'trump', 'wiretap', 'breitbart']
# ian mason salli yate say trump wiretap breitbart
# Joe Clark Maine s Gov  LePage Threatens To  Investigate  College Students For Fraud If They Vote  VIDEO
# joe clark maine s gov  lepage threatens to  investigate  college students for fraud if they vote  video
# ['joe', 'clark', 'maine', 's', 'gov', 'lepage', 'threatens', 'to', 'investigate', 'college', 'students', 'for', 'fraud', 'if', 'they', 'vote', 'video']
# ['joe', 'clark', 'main', 'gov', 'lepag', 'threaten', 'investig', 'colleg', 'student', 'fraud', 'vote', 'video']
# joe clark main gov lepag threaten investig colleg student fraud vote video
# Warner Todd Huston Sen  McConnell  The Supreme Court Vacancy Was Key to President Trump s Win   Breitbart
# warner todd huston sen  mcconnell  the supreme court vacancy was key to president trump s win   breitbart
# ['warner', 'todd', 'huston', 'sen', 'mcconnell', 'the', 'supreme', 'court', 'vacancy', 'was', 'key', 'to', 'president', 'trump', 's', 'win', 'breitbart']
# ['warner', 'todd', 'huston', 'sen', 'mcconnel', 'suprem', 'court', 'vacanc', 'key', 'presid', 'trump', 'win', 'breitbart']
# warner todd huston sen mcconnel suprem court vacanc key presid trump win breitbart
# Adam Shaw Nikki Haley Blasts U N  Human Rights Office for  Unfair Bias  Against Israel in Latest Report
# adam shaw nikki haley blasts u n  human rights office for  unfair bias  against israel in latest report
# ['adam', 'shaw', 'nikki', 'haley', 'blasts', 'u', 'n', 'human', 'rights', 'office', 'for', 'unfair', 'bias', 'against', 'israel', 'in', 'latest', 'report']
# ['adam', 'shaw', 'nikki', 'haley', 'blast', 'u', 'n', 'human', 'right', 'offic', 'unfair', 'bia', 'israel', 'latest', 'report']
# adam shaw nikki haley blast u n human right offic unfair bia israel latest report
# Daniel Greenfield Lawyer Who Kept Hillary Campaign Chief Out of Jail in DOJ Hillary Probe
# daniel greenfield lawyer who kept hillary campaign chief out of jail in doj hillary probe
# ['daniel', 'greenfield', 'lawyer', 'who', 'kept', 'hillary', 'campaign', 'chief', 'out', 'of', 'jail', 'in', 'doj', 'hillary', 'probe']
# ['daniel', 'greenfield', 'lawyer', 'kept', 'hillari', 'campaign', 'chief', 'jail', 'doj', 'hillari', 'probe']
# daniel greenfield lawyer kept hillari campaign chief jail doj hillari probe
# John Hayward Jakarta Bombing Kills Three Police Officers  Linked to Islamic State
# john hayward jakarta bombing kills three police officers  linked to islamic state
# ['john', 'hayward', 'jakarta', 'bombing', 'kills', 'three', 'police', 'officers', 'linked', 'to', 'islamic', 'state']
# ['john', 'hayward', 'jakarta', 'bomb', 'kill', 'three', 'polic', 'offic', 'link', 'islam', 'state']
# john hayward jakarta bomb kill three polic offic link islam state
# Robert Rich Idiot Who Destroyed Trump Hollywood Star Gets EXACTLY What He Deserves
# robert rich idiot who destroyed trump hollywood star gets exactly what he deserves
# ['robert', 'rich', 'idiot', 'who', 'destroyed', 'trump', 'hollywood', 'star', 'gets', 'exactly', 'what', 'he', 'deserves']
# ['robert', 'rich', 'idiot', 'destroy', 'trump', 'hollywood', 'star', 'get', 'exactli', 'deserv']
# robert rich idiot destroy trump hollywood star get exactli deserv
# Lee Stranahan Trump  Putin  Very Smart  to Not Retaliate over Obama Sanctions   Breitbart
# lee stranahan trump  putin  very smart  to not retaliate over obama sanctions   breitbart
# ['lee', 'stranahan', 'trump', 'putin', 'very', 'smart', 'to', 'not', 'retaliate', 'over', 'obama', 'sanctions', 'breitbart']
# ['lee', 'stranahan', 'trump', 'putin', 'smart', 'retali', 'obama', 'sanction', 'breitbart']
# lee stranahan trump putin smart retali obama sanction breitbart
# Jerome Hudson Rapper T I   Trump a  Poster Child For White Supremacy
# jerome hudson rapper t i   trump a  poster child for white supremacy
# ['jerome', 'hudson', 'rapper', 't', 'i', 'trump', 'a', 'poster', 'child', 'for', 'white', 'supremacy']
# ['jerom', 'hudson', 'rapper', 'trump', 'poster', 'child', 'white', 'supremaci']
# jerom hudson rapper trump poster child white supremaci
# Benjamin Hoffman N F L  Playoffs  Schedule  Matchups and Odds   The New York Times
# benjamin hoffman n f l  playoffs  schedule  matchups and odds   the new york times
# ['benjamin', 'hoffman', 'n', 'f', 'l', 'playoffs', 'schedule', 'matchups', 'and', 'odds', 'the', 'new', 'york', 'times']
# ['benjamin', 'hoffman', 'n', 'f', 'l', 'playoff', 'schedul', 'matchup', 'odd', 'new', 'york', 'time']
# benjamin hoffman n f l playoff schedul matchup odd new york time
# Michael J  de la Merced and Rachel Abrams Macy s Is Said to Receive Takeover Approach by Hudson s Bay   The New York Times
# michael j  de la merced and rachel abrams macy s is said to receive takeover approach by hudson s bay   the new york times
# ['michael', 'j', 'de', 'la', 'merced', 'and', 'rachel', 'abrams', 'macy', 's', 'is', 'said', 'to', 'receive', 'takeover', 'approach', 'by', 'hudson', 's', 'bay', 'the', 'new', 'york', 'times']
# ['michael', 'j', 'de', 'la', 'merc', 'rachel', 'abram', 'maci', 'said', 'receiv', 'takeov', 'approach', 'hudson', 'bay', 'new', 'york', 'time']
# michael j de la merc rachel abram maci said receiv takeov approach hudson bay new york time
# Alex Ansary NATO  Russia To Hold Parallel Exercises In Balkans
# alex ansary nato  russia to hold parallel exercises in balkans
# ['alex', 'ansary', 'nato', 'russia', 'to', 'hold', 'parallel', 'exercises', 'in', 'balkans']
# ['alex', 'ansari', 'nato', 'russia', 'hold', 'parallel', 'exercis', 'balkan']
# alex ansari nato russia hold parallel exercis balkan
# David Swanson What Keeps the F    Alive
# david swanson what keeps the f    alive
# ['david', 'swanson', 'what', 'keeps', 'the', 'f', 'alive']
# ['david', 'swanson', 'keep', 'f', 'aliv']
# david swanson keep f aliv

# %%
# separating the data & label
x = news_data['content'].values
print(x)
y= news_data['label'].values
print(y)
# Out:
# ['darrel lucu hous dem aid even see comey letter jason chaffetz tweet'
#  'daniel j flynn flynn hillari clinton big woman campu breitbart'
#  'consortiumnew com truth might get fire' ...
#  'michael j de la merc rachel abram maci said receiv takeov approach hudson bay new york time'
#  'alex ansari nato russia hold parallel exercis balkan'
#  'david swanson keep f aliv']
# [1 0 1 ... 0 1 1]

# %%
vectorizer = TfidfVectorizer()
vectorizer.fit(x)

x= vectorizer.transform(x)
print(x)
# Out:
#   (0, 15686)	0.28485063562728646
#   (0, 13473)	0.2565896679337957
#   (0, 8909)	0.3635963806326075
#   (0, 8630)	0.29212514087043684
#   (0, 7692)	0.24785219520671603
#   (0, 7005)	0.21874169089359144
#   (0, 4973)	0.233316966909351
#   (0, 3792)	0.2705332480845492
#   (0, 3600)	0.3598939188262559
#   (0, 2959)	0.2468450128533713
#   (0, 2483)	0.3676519686797209
#   (0, 267)	0.27010124977708766
#   (1, 16799)	0.30071745655510157
#   (1, 6816)	0.1904660198296849
#   (1, 5503)	0.7143299355715573
#   (1, 3568)	0.26373768806048464
#   (1, 2813)	0.19094574062359204
#   (1, 2223)	0.3827320386859759
#   (1, 1894)	0.15521974226349364
#   (1, 1497)	0.2939891562094648
#   (2, 15611)	0.41544962664721613
#   (2, 9620)	0.49351492943649944
#   (2, 5968)	0.3474613386728292
#   (2, 5389)	0.3866530551182615
#   (2, 3103)	0.46097489583229645
#   :	:
#   (20797, 13122)	0.2482526352197606
#   (20797, 12344)	0.27263457663336677
#   (20797, 12138)	0.24778257724396507
#   (20797, 10306)	0.08038079000566466
#   (20797, 9588)	0.174553480255222
#   (20797, 9518)	0.2954204003420313
#   (20797, 8988)	0.36160868928090795
#   (20797, 8364)	0.22322585870464118
#   (20797, 7042)	0.21799048897828688
#   (20797, 3643)	0.21155500613623743
#   (20797, 1287)	0.33538056804139865
#   (20797, 699)	0.30685846079762347
#   (20797, 43)	0.29710241860700626
#   (20798, 13046)	0.22363267488270608
#   (20798, 11052)	0.4460515589182236
#   (20798, 10177)	0.3192496370187028
#   (20798, 6889)	0.32496285694299426
#   (20798, 5032)	0.4083701450239529
#   (20798, 1125)	0.4460515589182236
#   (20798, 588)	0.3112141524638974
#   (20798, 350)	0.28446937819072576
#   (20799, 14852)	0.5677577267055112
#   (20799, 8036)	0.45983893273780013
#   (20799, 3623)	0.37927626273066584
#   (20799, 377)	0.5677577267055112

# %%
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, stratify=Y, random_state=2)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=41)

# %%
lg_model=LogisticRegression()
lg_model.fit(x_train,y_train)
lg_pred=lg_model.predict(x_test)
accuracy_score(y_test,lg_pred)
# Out:
# 0.9761217948717948
